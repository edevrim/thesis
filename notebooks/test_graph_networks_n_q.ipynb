# %% [markdown]
# # Cutting planes enhanced by GCN models and Q-learning for branching

# %%
# !pip install dgl
# Out:
# Collecting dgl
#   Downloading https://files.pythonhosted.org/packages/c5/b4/84e4ebd70ef3985181ef5d2d2a366a45af0e3cd18d249fb212ac03f683cf/dgl-0.4.3.post2-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 4.5MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from dgl) (1.4.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.6/dist-packages (from dgl) (2.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.6/dist-packages (from dgl) (2.23.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from dgl) (1.18.5)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.1->dgl) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->dgl) (2020.4.5.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->dgl) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->dgl) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->dgl) (3.0.4)
# Installing collected packages: dgl
# Successfully installed dgl-0.4.3.post2

# %%
# !pip install pulp
# Out:
# Collecting pulp
#   Downloading https://files.pythonhosted.org/packages/41/34/757c88c320f80ce602199603afe63aed1e0bc11180b9a9fb6018fb2ce7ef/PuLP-2.1-py3-none-any.whl (40.6MB)
#      |████████████████████████████████| 40.6MB 121kB/s
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from pulp) (2.4.7)
# Installing collected packages: pulp
# Successfully installed pulp-2.1

# %%
import numpy as np
import pandas as pd 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch as th

from copy import deepcopy
from datetime import datetime
import random 
from collections import deque
from dgl import DGLGraph
import seaborn as sns
import matplotlib.pyplot as plt 
import networkx as nx
from sklearn.manifold import TSNE
from google.colab import files
# Out:
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Using backend: pytorch
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# mijn functions
import actions_v12 as act
import graph_models_v17 as gm
# Out:
# Valid inequalities version: 9
# No hard restrictions for teeth assignments

# %% [markdown]
# **Champion GCN models**

# %%
# Models
GCN1 = gm.GCN5_MN(4, 256, 8, 0.2)
GCN1.load_state_dict(th.load("GCN1_JUN3.pth.tar"))
GCN1.eval()

GCN2 = gm.GCN5_MX(4, 256, 8, 0.2)
GCN2.load_state_dict(th.load("GCN2_JUN3.pth.tar"))
GCN2.eval()

GCN3 = gm.GCN5_SU(4, 256, 8, 0.2)
GCN3.load_state_dict(th.load("GCN3_JUN3.pth.tar"))
GCN3.eval()

GAT1 = gm.GAT3_MN(4, 16, 8, 8, 0.2)
GAT1.load_state_dict(th.load("GAT1_JUN4.pth.tar"))
GAT1.eval()

GAT2 = gm.GAT3_MX(4, 16, 8, 8, 0.2)
GAT2.load_state_dict(th.load("GAT2_JUN4.pth.tar"))
GAT2.eval()

GAT3 = gm.GAT3_SU(4, 16, 8, 8, 0.2)
GAT3.load_state_dict(th.load("GAT3_JUN4.pth.tar"))
GAT3.eval()

# Thresholds
# 0,1,2,3,4,5,7,8
tholds = [0.449, 0.343, 0.377, 0.274, 0.593, 0.336, 0.261, 0.223]

# %% [markdown]
# **Take actions**

# %%
def pick_actions(problem, tholds, model1, model2, model3, verbose):

    # 0: subtour elimination
    # 1: blossoms (basic combs)
    # 2: advanced comb
    # 3: clique tree
    # 4: blossom + path 
    # 5: bipartition
    # 6: envelope (NOT APPLICABLE)
    # 7: crown 8 
    # 8: crown multiple 
    
    graph1 = problem.graph 
    graph1.add_edges_from(zip(graph1.nodes(), graph1.nodes()))
    graph1 = DGLGraph(graph1)

    pred1, g_emb1, n_emb1 = model1(graph1)
    pred2, g_emb2, n_emb2 = model2(graph1)
    pred3, g_emb3, n_emb3 = model3(graph1)

    counter0 = 0 
    counter1 = 0 
    counter2 = 0 
    counter3 = 0 
    counter4 = 0 
    counter5 = 0 
    counter7 = 0 
    counter8 = 0 
    cycle_cutoff = 0.99 
    teeth_cutoff = 0.1
    teeth_cutoff_path = 1
    connection_check_flag = 1 # set this as 1 in order to avoid redundant constraints 
    false_alarm = 0
    true_alarm = 0

    # 0: subtour elimination (GCN1 - GCN3)
    action0 = 1 if (pred1[0][0].detach().item() + pred3[0][0].detach().item())/2 >= tholds[0] else 0 
    if action0 == 1: # go find isolated islands and add subtours 
        counter0 = problem.subtour_elimn()
        if counter0 > 0:
          true_alarm = true_alarm + 1
          if verbose == 1:
            print('yes, there were subtours indeed:', counter0)
        else: 
          false_alarm = false_alarm + 1
          if verbose == 1:
            print('nope, there were NO subtours, wrong prediction')

    # 1: basic blossom inequalities (GCN3)
    action1 = 1 if pred3[0][1].detach().item() >= tholds[1] else 0 
    if action1 == 1:
        counter1 = problem.find_multi_blossoms(cycle_cutoff, teeth_cutoff)
        if counter1 > 0:
          true_alarm = true_alarm + 1
          if verbose == 1:
            print('yes, there were blossoms indeed:', counter1)
        else: 
          false_alarm = false_alarm + 1
          if verbose == 1:
            print('nope, there were NO blossoms, wrong prediction')

    # 2: advanced comb inequalities (GCN3)
    action2 = 1 if pred3[0][2].detach().item() >= tholds[2] else 0 
    if action2 == 1: 
        counter2 = problem.find_adv_combs(cycle_cutoff, teeth_cutoff)
        if counter2 > 0:
          true_alarm = true_alarm + 1
          if verbose == 1:
            print('yes, there were advanced combs indeed:', counter2)
        else: 
          false_alarm = false_alarm + 1
          if verbose == 1:
            print('nope, there were NO advanced combs, wrong prediction')

    # 3: clique-tree inequality (GCN 1-2-3)
    action3 = 1 if (pred1[0][3].detach().item() + pred2[0][3].detach().item() + pred3[0][3].detach().item())/3 >= tholds[3] else 0 
    if action3 == 1: 
        counter3 = problem.find_clique_tree_2(cycle_cutoff, teeth_cutoff) 
        if counter3 > 0:
          counter3 = 1
          true_alarm = true_alarm + 1
          if verbose == 1:
            print('yes, there was a clique-tree indeed')
        else: 
          false_alarm = false_alarm + 1
          if verbose == 1:
            print('nope, there was NO clique-tree, wrong prediction')
        
    # 5: bipartiton inequality (GCN1 - GCN2)
    action5 = 1 if (pred1[0][5].detach().item() + pred2[0][5].detach().item())/2 >= tholds[5] else 0 
    if action5 == 1:
        counter5 = problem.find_bipartition(cycle_cutoff, teeth_cutoff) 
        if counter5 > 0:
          counter5 = 1
          true_alarm = true_alarm + 1
          if verbose == 1:
            print('yes, there was a bipartiton indeed')
        else: 
          false_alarm = false_alarm + 1
          if verbose == 1:
            print('nope, there was NO bipartition, wrong prediction')

    # 4: blossom and path inequality (GCN1 - GCN3)
    action4 = 1 if (pred1[0][4].detach().item() + pred3[0][4].detach().item())/2 >= tholds[4] else 0 
    if action4 == 1:
        counter4, xd1 = problem.find_blossom_n_path(cycle_cutoff, teeth_cutoff, teeth_cutoff_path) 
        if counter4 > 1:
          true_alarm = true_alarm + 1
          if verbose == 1:
            print('yes, there were blossom and following path indeed')
        elif counter4 == 1:
          true_alarm = true_alarm + 1
          if verbose == 1:
            print('hmm, there was only a blossom here')
        else: 
          false_alarm = false_alarm + 1
          if verbose == 1:
            print('nope, there were NO blossom and path, wrong prediction')

    # 7: crown with 8 subsets (GCN1 - GCN3)
    action7 = 1 if (pred1[0][6].detach().item() + pred3[0][6].detach().item())/2 >= tholds[6] else 0 
    if action7 == 1:
        counter7 = problem.find_crown_8(connection_check_flag)
        if counter7 > 1:
          true_alarm = true_alarm + 1
          counter7 = 1
          if verbose == 1:
            print('yes, there was a crown with 8 subsets indeed')
    
    # 8: crown with N subsets (GCN1 - GCN3)
    action8 = 1 if (pred1[0][7].detach().item() + pred3[0][7].detach().item())/2 >=  tholds[7] else 0 
    if action8 == 1: # go find advanced combs
        counter8 = problem.find_crown_more(connection_check_flag)
        if counter8 > 1:
          true_alarm = true_alarm + 1
          counter8 = 1
          if verbose == 1:
            print('yes, there was a crown with N subsets indeed')

    count_total = counter0 + counter1 + counter2 + counter3 + counter4 + counter5 + counter7 + counter8

    return problem, count_total, true_alarm, false_alarm

# %%
def plot_graph(problem1):
    
    # load nodes
    graph = nx.Graph()
    graph.add_nodes_from(problem1.node_list)
    
    if len(problem1.X_soln) > 0:
      
        for k in range(len(problem1.X_soln)):
            graph.add_edge(problem1.X_soln.loc[k][0], problem1.X_soln.loc[k][1], capacity=1.0)
         
        problem1.X_soln['color'] = problem1.X_soln.apply(lambda x: 'b' if x.x_value >= 0.99  else 'r', axis=1)
        colors = problem1.X_soln['color'].to_list()
    
        #set coordinates and plot
        nx.set_node_attributes(graph, problem1.coordinates_dict, 'pos')    
        nx.draw(graph, nx.get_node_attributes(graph, 'pos'), with_labels = True, edge_color=colors)
        #plt.savefig("simple_path.png") 
        plt.show()

# %% [markdown]
# **Qnet agent**

# %%
class QTSP:
    def __init__(self, input_dim, output_dim, discount_rate, epochs):
        # initialize atributes
        self._input_size = input_dim
        self._action_size = output_dim
        self.discount_rate = discount_rate 
        self.epochs = epochs
        #self.loss_func = nn.MSELoss()
        
        # memory to keep state-action-reward-next state
        self.memo = deque(maxlen=50000)

        # build networks
        #WARNINGG
        self.q_network = self.build_compile_model() # q network to predict q values
        self.optimizer = optim.RMSprop(self.q_network.parameters())
        self.target_network = self.build_compile_model() # target network as frozen version of q network
        self.align_target_model() # align weights
        self.target_network.eval()
    
    def store(self, state, action, reward, next_state, complete_flag):
        self.memo.append((state, action, reward, next_state, complete_flag))
    
    def build_compile_model(self):
        model = gm.NNN_(self._input_size, self._action_size, 0.1)
        return model

    def align_target_model(self):
        # align weights
        self.target_network.load_state_dict(self.q_network.state_dict())
    
    def act(self, state, exploration_rate):
        if np.random.rand() <= exploration_rate:
            return random.randint(0, self._action_size-1)
        else:
            q_values = self.q_network(state) # predict state (graph)
            print("this action is QMAX:", np.argmax(q_values.detach().numpy()))
            return np.argmax(q_values.detach().numpy())

    def retrain(self, batch_size, loss_list):
        minibatch = random.sample(self.memo, batch_size)
        print("training now")
        self.q_network.train()

        for epoch in range(self.epochs):
            for state, action, reward, next_state, complete_flag in minibatch:
                
                target = self.q_network(state)
        
                if complete_flag == 1:
                    target[action] = reward
                else:
                    # predict next state's q-value via target (2nd) network 
                    t = self.target_network(next_state)
                    target[action] = reward + self.discount_rate * np.amax(t.detach().numpy())
                
                prediction = self.q_network(state)
                loss = F.smooth_l1_loss(prediction, target)
                loss_list.append(loss.detach().numpy())
                self.optimizer.zero_grad() 
                loss.backward(retain_graph=True)
                self.optimizer.step()
        return loss_list

# %% [markdown]
# **Functions for reward, branch-check and state**

# %%
def check_branch(problem):

  soln = problem.X_soln 
  fractional = soln[soln.x_value < 1]
  if len(fractional) > 0: 
    branch_flag = 1
  else:
    branch_flag = 0

  return branch_flag

# define state
def define_state(problem, model1, model2):
  
  graph1 = problem.graph 
  graph1.add_edges_from(zip(graph1.nodes(), graph1.nodes()))
  graph1 = DGLGraph(graph1)

  h = pd.DataFrame(graph1.in_degrees().detach().numpy()).reset_index(drop=False) 
  h = list(h[h[0] == h[0].max()]['index'])
  
  pred1, g_emb1, n_emb1 = model1(graph1)
  pred2, g_emb2, n_emb2 = model2(graph1)

  soln = problem.X_soln 
  fractional = soln[soln.x_value < 1]
  list0 = list(set(list(fractional['origin'].append(fractional['destination']))))

  h2 = [item for item in h if item in list0]

  if len(fractional) > 0:
    if len(h2) > 0:
      node = h2[0]
      list1 = list(fractional[fractional['origin'] == node]['destination'].append(fractional[fractional['destination'] == node]['origin']))
      if len(list1) > 0:
        connection = list1[0]
        regret = [item for item in list1 if item != connection]  
        if len(regret) > 0:
          regret = regret[0] 
        else:
          regret = -1
      else:
        connection = -1
        regret = -1
    else: 
      node = fractional['origin'].iloc[0]
      connection = fractional['destination'].iloc[0]
      list1 = list(fractional[fractional['origin'] == node]['destination'].append(fractional[fractional['destination'] == node]['origin']))
      regret = [item for item in list1 if item != connection]
      if len(regret) > 0:
       regret = regret[0] 
      else:
       regret = -1
  
  if connection < 0 or regret < 0:
    node = soln['origin'].iloc[0] #pick the first line
    connection = soln['destination'].iloc[0]
    list1 = list(soln[soln['origin'] == node]['destination'].append(soln[soln['destination'] == node]['origin']))
    regret = [item for item in list1 if item != connection]
    if len(regret) > 0:
      regret = regret[0] 
    else:
      regret = connection
  
  xd1 = n_emb1[node].view(-1, 1).float() + n_emb1[connection].view(-1, 1).float()
  xd2 = n_emb1[node].view(-1, 1).float() + n_emb1[regret].view(-1, 1).float()

  xd3 = n_emb2[node].view(-1, 1).float() + n_emb2[connection].view(-1, 1).float()
  xd4 = n_emb2[node].view(-1, 1).float() + n_emb2[regret].view(-1, 1).float() 

  state = th.cat((xd1, xd3, xd2, xd4), 0)
  state = state.view(-1)

  return state, node, connection, regret

def add_valid_ineq(problem1, constraint_count):
  
  old_solution = problem1.X_soln[['origin', 'destination', 'x_value']]
  #problem1, count_total, true_alarm, false_alarm = pick_actions(problem1, tholds, GCN1, GCN2, GCN3, 0)     
  # ONLY SUBTOUR ELIMINATION CONSTRAINTS ADDED FOR SIMPLICITY
  count_total = problem1.subtour_elimn()

  problem1.solve_lp_relax()
  new_solution = problem1.X_soln[['origin', 'destination', 'x_value']]
  change_flag = 1 - int(old_solution.equals(new_solution))

  if change_flag == 1:
    constraint_count = constraint_count + count_total 
    problem1.graph = problem1.create_graph()
    problem1.check_if_complete()

  return problem1, change_flag, constraint_count


def check_regret(problem, connection, regret):
  xd1 = problem.X_soln
  xd1 = xd1[xd1['x_value'] == 1]
  check1 = xd1[(xd1['origin'] == connection) & (xd1['destination'] == regret)]
  check2 = xd1[(xd1['origin'] == regret) & (xd1['destination'] == connection)]
  if len(check1) + len(check2) >= 1:
    check_regret = 1
  else:
    check_regret = 0

  return check_regret

# %% [markdown]
# **Train/Test instances**

# %% [markdown]
# **TSP list**

# %%
test_tsp_list = [
(38,'TestTSP0_3.csv'),
(734,'TestTSP14_3.csv'),
(839,'TestTSP16_9.csv'),
(844,'TestTSP16_14.csv'),
(183,'TestTSP3_14.csv'),
(445,'TestTSP8_12.csv'),
(791,'TestTSP15_11.csv'),
(346,'TestTSP6_13.csv'),
(495,'TestTSP9_12.csv'),
(944,'TestTSP18_14.csv'),
(90,'TestTSP1_5.csv'),
(285,'TestTSP5_2.csv'),
(148,'TestTSP2_13.csv'),
(136,'TestTSP2_1.csv'),
(546,'TestTSP10_13.csv'),
(841,'TestTSP16_11.csv'),
(41,'TestTSP0_6.csv'),
(438,'TestTSP8_5.csv'),
(433,'TestTSP8_0.csv'),
(883,'TestTSP17_3.csv'),
(42,'TestTSP0_7.csv'),
(442,'TestTSP8_9.csv'),
(94,'TestTSP1_9.csv'),
(44,'TestTSP0_9.csv'),
(397,'TestTSP7_14.csv'),
(43,'TestTSP0_8.csv'),
(142,'TestTSP2_7.csv'),
(287,'TestTSP5_4.csv'),
(788,'TestTSP15_8.csv'),
(98,'TestTSP1_13.csv'),
(46,'TestTSP0_11.csv'),
(780,'TestTSP15_0.csv'),
(87,'TestTSP1_2.csv'),
(689,'TestTSP13_8.csv'),
(283,'TestTSP5_0.csv'),
(632,'TestTSP12_1.csv'),
(292,'TestTSP5_9.csv'),
(742,'TestTSP14_11.csv'),
(288,'TestTSP5_5.csv'),
(91,'TestTSP1_6.csv'),
(96,'TestTSP1_11.csv'),
(681,'TestTSP13_0.csv'),
(297,'TestTSP5_14.csv'),
(888,'TestTSP17_8.csv'),
(793,'TestTSP15_13.csv'),
(685,'TestTSP13_4.csv'),
(89,'TestTSP1_4.csv'),
(185,'TestTSP3_0.csv'),
(145,'TestTSP2_10.csv'),
(439,'TestTSP8_6.csv'),
(785,'TestTSP15_5.csv'),
(694,'TestTSP13_13.csv'),
(247,'TestTSP4_14.csv'),
(537,'TestTSP10_4.csv'),
(938,'TestTSP18_8.csv'),
(241,'TestTSP4_8.csv'),
(383,'TestTSP7_0.csv'),
(238,'TestTSP4_5.csv'),
(233,'TestTSP4_0.csv'),
(931,'TestTSP18_1.csv'),
(235,'TestTSP4_2.csv'),
(588,'TestTSP11_5.csv'),
(240,'TestTSP4_7.csv'),
(242,'TestTSP4_9.csv'),
(244,'TestTSP4_11.csv'),
(591,'TestTSP11_8.csv'),
(237,'TestTSP4_4.csv'),
(385,'TestTSP7_2.csv'),
(583,'TestTSP11_0.csv'),
(393,'TestTSP7_10.csv'),
(246,'TestTSP4_13.csv'),
(587,'TestTSP11_4.csv'),
(592,'TestTSP11_9.csv'),
(586,'TestTSP11_3.csv'),
(584,'TestTSP11_1.csv'),
(239,'TestTSP4_6.csv'),
(590,'TestTSP11_7.csv'),
(243,'TestTSP4_10.csv'),
(783,'TestTSP15_3.csv')
]

# %%
print('number of instances:', len(test_tsp_list))
# Out:
# number of instances: 164

# %% [markdown]
# # Q-Network and Cutting Planes together

# %% [markdown]
# **Define the agent**

# %%
action_size = 6
input_size = 128 * 2 + 256*2
batch_size = 64

loss_list = []
cp_qnet_test = pd.DataFrame()
agent = QTSP(input_size, action_size, 0.99, 3) 
MODEL_TAG = 'JUN18'

# %% [markdown]
# **Load trained agent**

# %%
agent.q_network.load_state_dict(th.load("GCN_QNET_"+MODEL_TAG+".pth.tar"))
#agent.target_network.load_state_dict(th.load("GCN_TARGETNET_"+MODEL_TAG+".pth.tar"))
agent.q_network.eval()
# Out:
# NNN_(
#   (layer1): Linear(in_features=768, out_features=768, bias=True)
#   (drop_layer1): Dropout(p=0.1, inplace=False)
#   (layer2): Linear(in_features=768, out_features=384, bias=True)
#   (drop_layer2): Dropout(p=0.1, inplace=False)
#   (layer3): Linear(in_features=384, out_features=192, bias=True)
#   (drop_layer3): Dropout(p=0.1, inplace=False)
#   (layer4): Linear(in_features=192, out_features=6, bias=True)
# )

# %% [markdown]
# # Solve Test instances

# %%
for k in range(81, len(test_tsp_list)): 

  tsp_id = test_tsp_list[k][0]
  data_name = test_tsp_list[k][1]
  problem1 = act.init_prob(tsp_id, data_name, 0, 'continuous') 
  initial_objective = problem1.objective_val
  
  # show the initial solution
  #print('initial tour')
  #plot_graph(problem1)
  constraint_count = 0
  branch_count = 0 
  action_sum = 0

  true_alarm_count = 0
  false_alarm_count = 0
  con_limit = 500
  change_flag = 1
  break_flag = 0 

  start_time = datetime.now()
  print("iteration:", k)
  print("running for tsp:", tsp_id, "start time:", start_time)

  while (constraint_count + branch_count) <= con_limit and problem1.complete_flag == 0:

    if break_flag == 1:
      break # while loop
  
    if change_flag == 0 or (constraint_count + branch_count) > con_limit/5: # keep branching either after some time as well
      # Do branching if it's possible 
      branch_flag = check_branch(problem1)
      
      if branch_flag == 1: 
        branch_count = branch_count + 1
        state, node, connection, regret = define_state(problem1, GAT3, GCN1)
        q_values = agent.q_network(state)
        print('q values are:', q_values.detach().numpy())
        #plot_graph(problem1)
        action = np.argmax(q_values.detach().numpy())
        if action > 3: 
          c_regret = check_regret(problem1, connection, regret)
          if c_regret == 1: 
            action = np.argmax(q_values.detach().numpy()[0:4])
                    
        action_sum = action_sum + action
        print('branching now, action is:', action, node, connection, regret)
      
        # take the action    
        problem1 = act.add_branch(problem1, node, connection, regret, action)
        problem1.solve_lp_relax()
        problem1.graph = problem1.create_graph()
        problem1.check_if_complete()

      elif branch_flag == 0 and change_flag == 0:
        break_flag = 1 # no more rooms to search through 
   
    # Also keep adding valid inequalities
    old_solution = problem1.X_soln[['origin', 'destination', 'x_value']]
    problem1, count_total, true_alarm, false_alarm = pick_actions(problem1, tholds, GCN1, GCN2, GCN3, 0)

    problem1.solve_lp_relax() 
    new_solution = problem1.X_soln[['origin', 'destination', 'x_value']]
    change_flag = 1 - int(old_solution.equals(new_solution))
    constraint_count = constraint_count + count_total    

    if change_flag == 1:
      true_alarm_count = true_alarm_count + true_alarm
      false_alarm_count = false_alarm_count + false_alarm
      problem1.graph = problem1.create_graph()
      problem1.check_if_complete()
    
    elif change_flag == 0:
      false_alarm_count = false_alarm_count + constraint_count 

  end_time = datetime.now()
  #print('final tour')
  #plot_graph(problem1)
  problem1.check_if_complete()
  if problem1.complete_flag == 0:
    print('tour is NOT complete, branching needed!')
  else: 
    print('tour is complete!')
    print('objective_val', problem1.objective_val)

  obj1 = {'tsp_id': tsp_id, 
            'initial_objective': initial_objective, 
            'final_objective' : problem1.objective_val, 
            'start_time': start_time, 
            'end_time': end_time, 
            'complete_flag':problem1.complete_flag, 
            'n_of_constraint': constraint_count, 
            'n_of_branch': branch_count,
            'action_sum':action_sum,
            'true_alarm': true_alarm_count, 
            'false_alarm': false_alarm_count,
            'con_limit': con_limit
          }
  cp_qnet_test = cp_qnet_test.append(pd.DataFrame(obj1, index=[0]))

# download the output
cp_qnet_test.to_csv('CPQ_test_perfo.csv')
files.download('CPQ_test_perfo.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# q values are: [20.194447 15.178723 23.986702 10.857274 19.041786 21.481552]
# branching now, action is: 2 41 42 43
# q values are: [20.699461 15.36964  23.385155 11.609417 19.29582  22.048775]
# branching now, action is: 2 62 69 53
# q values are: [19.020584 14.109396 21.496956 12.636678 17.615341 22.176216]
# branching now, action is: 5 19 22 35
# q values are: [22.344357 15.886289 25.913177 11.297845 20.609398 24.085682]
# branching now, action is: 2 99 100 101
# q values are: [22.14153  15.736742 24.2262   12.425621 20.247892 24.0858  ]
# branching now, action is: 2 101 103 104
# q values are: [20.633287 12.004335 20.805576 14.430344 16.032534 22.449455]
# branching now, action is: 5 42 28 29
# tour is NOT complete, branching needed!
# iteration: 91
# running for tsp: 40 start time: 2020-06-19 19:48:23.086221
# q values are: [22.218452 15.972099 24.990059 11.734425 20.405546 23.750748]
# branching now, action is: 2 63 85 15
# q values are: [20.393387 15.308397 24.23864  10.777986 19.210236 21.616497]
# branching now, action is: 2 6 18 71
# q values are: [22.73613  14.667425 26.35413  12.17081  19.69616  27.017452]
# branching now, action is: 5 72 81 83
# q values are: [23.98602  16.091957 26.072216 12.824251 21.60434  26.648598]
# branching now, action is: 5 2 19 22
# q values are: [20.327616 15.236324 23.608046 11.060562 19.064941 21.535845]
# branching now, action is: 2 31 63 85
# q values are: [20.026112 15.990784 22.07734  12.810812 17.162766 23.95882 ]
# branching now, action is: 5 4 43 65
# q values are: [18.876625 14.946649 21.861446 10.741203 18.142403 19.585136]
# branching now, action is: 2 56 60 66
# q values are: [18.862583 14.86087  22.731457 10.822907 18.254307 20.191586]
# branching now, action is: 2 52 56 61
# q values are: [19.04738  14.821089 22.703758 11.218597 18.078043 20.765804]
# branching now, action is: 2 52 56 66
# q values are: [19.710129 15.168498 23.323082 10.466558 18.909035 20.57203 ]
# branching now, action is: 2 58 1 7
# q values are: [19.710129  15.168498  23.323082  10.4665575 18.909035  20.57203  ]
# branching now, action is: 2 58 1 49
# q values are: [16.449429 14.066156 17.843662 11.324584 16.10667  16.330118]
# branching now, action is: 2 20 30 60
# tour is complete!
# objective_val 7676.0
# iteration: 92
# running for tsp: 48 start time: 2020-06-19 19:51:41.543539
# q values are: [18.668175 14.835473 22.314844 11.168409 17.808197 20.411104]
# branching now, action is: 2 24 31 73
# q values are: [18.304852 14.479303 21.567326 11.664668 17.295753 20.599396]
# branching now, action is: 2 24 31 66
# q values are: [20.972586 15.071014 23.894588 11.870644 19.383022 23.19646 ]
# branching now, action is: 2 24 31 80
# q values are: [31.55437   3.030796 17.10944  35.676003 13.10937  28.308804]
# branching now, action is: 3 96 108 15
# q values are: [17.343754 14.296648 19.99828  11.324839 16.835667 18.236526]
# branching now, action is: 2 14 66 73
# q values are: [21.610832  15.744835  25.922665  10.3840275 20.167747  22.793514 ]
# branching now, action is: 2 29 32 62
# q values are: [12.63883  17.322792  9.878101 47.264084 10.474911 43.69713 ]
# branching now, action is: 3 92 109 9
# q values are: [17.590054 14.418363 20.412987 11.146875 17.04107  18.466185]
# branching now, action is: 2 28 50 56
# q values are: [17.447773 14.400866 19.84961  11.199322 16.69116  18.044523]
# branching now, action is: 2 31 80 90
# q values are: [17.403868 14.442273 19.673107 11.130742 16.848068 17.84927 ]
# branching now, action is: 2 8 17 26
# q values are: [17.273462 15.81566  22.12878  15.629711 17.110664 28.123089]
# branching now, action is: 5 11 33 54
# q values are: [18.448112 14.721384 21.370712 10.812535 17.839603 19.070396]
# branching now, action is: 2 23 29 99
# q values are: [ 25.683857    7.8067455  -8.667392  108.20978    -8.045538   57.50661  ]
# branching now, action is: 3 106 25 37
# q values are: [22.850002 15.897921 25.992508 11.664284 21.016685 24.782448]
# branching now, action is: 2 41 42 52
# q values are: [17.012161 14.182948 19.265001 11.233358 16.56311  17.442524]
# branching now, action is: 2 31 65 80
# tour is NOT complete, branching needed!
# iteration: 93
# running for tsp: 541 start time: 2020-06-19 19:58:16.036460
# q values are: [17.594055 14.329355 20.337196 11.222334 16.529938 18.458967]
# branching now, action is: 2 1 2 42
# q values are: [  -3.5069761   11.829852  -482.68143    949.5608    -273.77954
#    52.620487 ]
# branching now, action is: 3 40 41 60
# q values are: [25.822554  9.677013 20.627022 21.806963 15.886646 25.43708 ]
# branching now, action is: 0 27 28 30
# q values are: [ -7.4276648  11.268638  -45.015358  203.9165    -25.09692    96.827324 ]
# branching now, action is: 3 59 60 36
# q values are: [ -26.248547    -6.2464266 -496.28577    969.39276   -322.10687
#    46.26376  ]
# branching now, action is: 3 27 30 31
# q values are: [ 108.30779    16.249157 -357.88837   795.34717  -189.10118    80.50265 ]
# branching now, action is: 3 37 38 39
# q values are: [ -88.725716  -28.946571 -270.37952   490.72495  -223.1909     59.848385]
# branching now, action is: 3 30 31 27
# q values are: [38.96275   20.210468  52.812416   6.6999846 34.294384  43.978737 ]
# branching now, action is: 2 24 25 34
# q values are: [ 131.1423     27.369343 -124.02365   396.46503   -52.72055   103.8103  ]
# branching now, action is: 3 38 39 41
# q values are: [21.118084  15.4520645 24.885452  10.97217   19.729885  22.619417 ]
# branching now, action is: 2 33 34 58
# q values are: [33.254402  19.552765  44.50319    7.7669806 29.847801  37.60555  ]
# branching now, action is: 2 22 23 58
# tour is complete!
# objective_val 9721.0
# iteration: 94
# running for tsp: 234 start time: 2020-06-19 20:00:53.622212
# q values are: [17.867886 14.633764 20.191881 11.060926 17.188751 18.401688]
# branching now, action is: 2 15 16 27
# q values are: [17.587368 14.776023 20.0032   11.143027 16.76987  18.699179]
# branching now, action is: 2 15 16 23
# q values are: [22.086796 15.170015 23.827358 12.475012 19.889196 24.206753]
# branching now, action is: 5 15 37 38
# q values are: [19.796618 15.232529 23.644024 10.49933  18.85611  21.043888]
# branching now, action is: 2 15 16 37
# q values are: [18.038088 14.594073 20.485739 10.891446 17.46582  18.357782]
# branching now, action is: 2 15 16 31
# q values are: [24.539413 16.346272 30.597427  9.644385 22.613201 26.356583]
# branching now, action is: 2 15 16 36
# q values are: [21.955677 16.05031  26.744482 10.33533  20.255234 24.218468]
# branching now, action is: 2 15 16 38
# q values are: [19.016064 14.17584  20.636864 12.408761 17.554071 21.171165]
# branching now, action is: 5 28 30 31
# q values are: [18.862013 14.89347  22.196552 10.783038 18.103043 19.900063]
# branching now, action is: 2 30 2 6
# q values are: [17.647205 14.541085 20.095306 11.099608 16.979801 18.33134 ]
# branching now, action is: 2 30 1 2
# q values are: [37.87199   18.607773  50.996128   6.7831707 31.135733  42.552322 ]
# branching now, action is: 2 10 15 36
# q values are: [24.44487  16.585567 32.102127  9.133997 23.319689 26.809566]
# branching now, action is: 2 10 12 15
# q values are: [20.584957 15.215883 22.72062  12.10001  19.170057 22.154669]
# branching now, action is: 2 10 12 20
# q values are: [16.903576  14.027952  19.256927  11.6543045 16.322273  18.175507 ]
# branching now, action is: 2 30 36 15
# q values are: [25.131405 16.4271   31.592667  9.320425 23.186968 27.102036]
# branching now, action is: 2 12 15 20
# q values are: [20.204842 15.217495 24.724613 11.102182 18.877018 22.858662]
# branching now, action is: 2 72 75 45
# q values are: [21.041147 15.483385 25.031673 10.624229 19.633629 22.216919]
# branching now, action is: 2 49 53 59
# q values are: [20.349554 15.600554 24.927067 10.629654 19.083408 22.704166]
# branching now, action is: 2 72 48 55
# q values are: [16.995426 14.434952 19.350883 11.355538 16.377329 18.00059 ]
# branching now, action is: 2 61 68 47
# q values are: [17.250645 13.986486 19.75616  11.836106 16.633137 18.952753]
# branching now, action is: 2 61 68 71
# q values are: [28.707703 17.611954 37.968548  8.127689 26.392452 31.571285]
# branching now, action is: 2 7 34 36
# q values are: [-136.41193    38.427135 -144.94217   310.02835   -69.661865    8.849172]
# branching now, action is: 3 54 67 76
# q values are: [39.05681   20.50666   53.384243   6.7735076 34.389984  44.61583  ]
# branching now, action is: 2 7 10 34
# q values are: [18.831024 14.825388 22.209803 10.763456 18.221863 19.712757]
# branching now, action is: 2 64 72 75
# q values are: [18.144718 14.592411 21.096233 11.093062 17.390047 19.181015]
# branching now, action is: 2 30 1 27
# q values are: [19.240515 15.013387 22.414497 10.610986 18.494259 19.920021]
# branching now, action is: 2 34 35 8
# q values are: [18.921192 14.059429 18.340992 23.868645 15.219535 28.758503]
# branching now, action is: 5 64 72 51
# q values are: [-117.351006  -25.855366 -327.63428   573.5002   -273.1339     27.112778]
# branching now, action is: 3 60 67 70
# q values are: [20.00986  15.13682  23.686607 10.412441 19.174385 20.733765]
# branching now, action is: 2 22 24 17
# q values are: [15.692419   9.3962345 20.928349  13.613716  13.066565  18.312614 ]
# branching now, action is: 2 7 10 2
# q values are: [16.66852  14.265695 18.392776 11.33311  16.025381 17.087503]
# branching now, action is: 2 13 32 0
# q values are: [-60.937786  15.702132 -92.21625  246.9285   -85.7545    58.0563  ]
# branching now, action is: 3 45 50 60
# q values are: [19.186634 14.897461 22.310371 10.61635  18.459507 19.690802]
# branching now, action is: 2 13 32 1
# q values are: [27.809074 17.17614  35.923016  8.621561 25.282005 30.246609]
# branching now, action is: 2 1 9 30
# q values are: [  62.398796   15.780681 -260.1582    608.93365  -142.23769    96.472046]
# branching now, action is: 3 56 58 59
# tour is NOT complete, branching needed!
# iteration: 95
# running for tsp: 631 start time: 2020-06-19 20:10:14.230574
# q values are: [18.10368  14.553821 21.270538 10.947344 17.604635 18.945824]
# branching now, action is: 2 20 21 22
# q values are: [ 109.49177    15.559901 -295.10327   688.01483  -151.95888    85.42274 ]
# branching now, action is: 3 5 6 7
# q values are: [36.01092   -2.2700157 17.985535  39.63382   11.093859  31.231392 ]
# branching now, action is: 3 9 18 19
# q values are: [22.838615 16.114254 27.826103  9.879156 21.304413 24.054771]
# branching now, action is: 2 15 16 23
# q values are: [21.223782 15.505337 26.877102  9.811928 20.767925 22.907772]
# branching now, action is: 2 2 4 5
# q values are: [16.784288 14.1507   19.447426 11.584721 16.762379 17.834654]
# branching now, action is: 2 20 23 9
# q values are: [22.590288 16.056974 27.698822  9.697237 21.499098 23.57241 ]
# branching now, action is: 2 4 5 6
# q values are: [41.740612 20.942772 57.70022   5.550284 36.581017 46.900738]
# branching now, action is: 2 0 3 10
# q values are: [ 9.82707  12.447362 19.182896 17.012592 12.899352 13.729332]
# branching now, action is: 2 3 4 0
# q values are: [17.093842 14.178051 19.538216 11.388139 16.617226 17.859118]
# branching now, action is: 2 20 23 10
# q values are: [27.32239  17.572998 35.28339   8.517527 25.393017 29.066181]
# branching now, action is: 2 0 2 11
# q values are: [17.774769  14.4870205 20.066063  11.095711  17.168358  18.266233 ]
# branching now, action is: 2 20 23 12
# q values are: [21.66996   15.6819935 25.92966   10.396901  20.156128  22.810648 ]
# branching now, action is: 2 15 26 13
# q values are: [18.506294 14.557934 22.218136 12.060162 17.520378 21.477459]
# branching now, action is: 2 5 6 8
# q values are: [19.468834 14.952803 23.01041  10.919644 18.54757  20.611137]
# branching now, action is: 2 23 25 26
# q values are: [15.740689 13.783594 17.015736 11.602004 15.527151 15.822894]
# branching now, action is: 2 23 24 12
# q values are: [22.73565  16.087212 27.746735 10.044291 21.128386 24.112492]
# branching now, action is: 2 20 21 29
# q values are: [17.655176 14.108641 20.441242 11.861892 16.866978 19.806   ]
# branching now, action is: 2 13 14 23
# q values are: [19.531311  14.895252  23.258692  10.9809475 18.576235  20.928532 ]
# branching now, action is: 2 18 19 20
# q values are: [17.354208 14.296351 19.677967 11.16237  16.852234 17.817047]
# branching now, action is: 2 18 19 22
# q values are: [20.263916  15.084945  22.887796  11.6579685 18.988735  21.675282 ]
# branching now, action is: 2 18 19 21
# q values are: [17.52253  14.288676 20.377708 11.256967 16.996454 18.538626]
# branching now, action is: 2 32 18 21
# q values are: [10.96352   21.409054  -2.5368118 84.25813    2.1528568 56.546165 ]
# branching now, action is: 3 42 44 33
# tour is complete!
# objective_val 9834.0
# iteration: 96
# running for tsp: 534 start time: 2020-06-19 20:12:37.321283
# q values are: [23.374607 13.883784 25.042606 12.134681 19.035349 25.478432]
# branching now, action is: 5 44 56 59
# q values are: [24.06394  16.609411 27.105713 12.064629 21.79655  26.17265 ]
# branching now, action is: 2 2 3 4
# q values are: [24.2715   16.667322 27.97464  11.710894 22.028416 26.48161 ]
# branching now, action is: 2 3 4 45
# q values are: [22.526394  11.697996  23.406582  13.4498825 17.105228  24.7961   ]
# branching now, action is: 5 1 2 3
# q values are: [-164.83496    21.355255  -76.9244    190.23627   -45.87866   -25.954151]
# branching now, action is: 3 1 2 3
# q values are: [23.279888 16.274557 28.805592  9.581142 22.072025 24.424112]
# branching now, action is: 2 22 23 53
# q values are: [26.97694  18.269398 36.160683 11.33712  23.934155 31.525948]
# branching now, action is: 2 9 10 31
# q values are: [18.198212 14.332161 21.05818  12.236742 16.91345  20.954666]
# branching now, action is: 2 25 29 30
# q values are: [ -44.75271      2.0152922 -176.58655    388.1292    -151.67705
#    77.220055 ]
# branching now, action is: 3 27 28 58
# q values are: [ 1.8167562 15.933176  -7.399602  90.04741   -2.8873997 74.714714 ]
# branching now, action is: 3 55 58 59
# q values are: [16.707504 14.098056 19.569016 11.837276 16.604946 18.011456]
# branching now, action is: 2 25 28 29
# q values are: [27.41391  17.477951 35.402004  8.568342 25.520725 29.43015 ]
# branching now, action is: 2 40 42 52
# q values are: [19.030758 14.879843 22.087505 10.610192 18.358015 19.459887]
# branching now, action is: 2 50 52 60
# q values are: [-10.846728    6.6247125  11.934325   23.899046   -4.828451   14.313612 ]
# branching now, action is: 3 54 66 41
# tour is complete!
# objective_val 13735.0
# iteration: 98
# running for tsp: 838 start time: 2020-06-19 20:29:42.592527
# q values are: [21.251373 15.645313 26.054497 10.174429 20.110023 22.885693]
# branching now, action is: 2 64 67 70
# q values are: [16.260904 14.010032 17.605436 11.38536  15.963861 16.169073]
# branching now, action is: 2 20 24 54
# q values are: [23.046244 16.184757 28.247795 10.098336 21.329477 24.632183]
# branching now, action is: 2 106 107 72
# q values are: [16.460484 14.026017 18.457237 11.366001 16.123093 16.858536]
# branching now, action is: 2 58 60 61
# q values are: [21.483757 15.589963 25.81974  10.79493  20.069122 23.16257 ]
# branching now, action is: 2 99 105 106
# q values are: [ 74.78774   19.511066 -36.76867  204.44095   -7.84004  110.36974 ]
# branching now, action is: 3 38 39 40
# q values are: [21.052258 15.437635 25.897484 10.538612 19.916002 22.871748]
# branching now, action is: 2 20 21 22
# q values are: [23.13369  16.39173  29.007679  9.97309  21.365599 25.867964]
# branching now, action is: 2 64 65 67
# q values are: [18.200771 14.609215 20.627972 10.83408  17.655056 18.398634]
# branching now, action is: 2 64 65 69
# q values are: [25.74173  16.699797 32.31163   9.272033 23.625229 27.595978]
# branching now, action is: 2 64 65 91
# q values are: [14.802176   9.3535595  3.9759579 61.82058   -1.3442564 42.803825 ]
# branching now, action is: 3 110 112 113
# q values are: [20.466013 15.19172  24.14906  11.25557  19.1703   22.27647 ]
# branching now, action is: 2 105 106 107
# q values are: [22.737465 16.067719 27.72924  10.186248 21.08519  24.250652]
# branching now, action is: 2 20 21 55
# q values are: [16.279778   6.761218  10.584955  43.935783   6.0391445 29.944675 ]
# branching now, action is: 3 40 41 42
# q values are: [22.71265  15.947734 28.299885 10.462818 21.058334 24.940027]
# branching now, action is: 2 58 60 54
# q values are: [17.322605 14.362083 19.334766 11.012001 16.916899 17.391647]
# branching now, action is: 2 105 106 64
# q values are: [19.973675 15.136887 23.334    10.314523 18.976028 20.295198]
# branching now, action is: 2 36 37 38
# q values are: [21.41333  15.597811 25.26241  10.8977   19.93952  22.873035]
# branching now, action is: 2 108 112 116
# q values are: [17.336662 14.440889 19.44402  11.121201 16.794199 17.695051]
# branching now, action is: 2 41 42 44
# q values are: [21.205402  15.3632765 24.063034  11.63137   19.730213  22.832909 ]
# branching now, action is: 2 58 59 60
# q values are: [20.896263 15.451586 24.912941 10.517336 19.641577 22.009226]
# branching now, action is: 2 64 65 99
# q values are: [18.833616  14.7971525 21.965317  10.594844  18.192972  19.417576 ]
# branching now, action is: 2 58 59 55
# q values are: [18.079226 14.557042 21.020424 11.183079 17.50087  18.859106]
# branching now, action is: 2 57 58 59
# q values are: [17.652273 14.518667 21.115253 11.293162 17.50413  19.084694]
# branching now, action is: 2 100 104 105
# tour is NOT complete, branching needed!
# iteration: 99
# running for tsp: 692 start time: 2020-06-19 20:48:06.119514
# q values are: [17.824408 14.416376 20.671227 11.426211 17.070408 19.177216]
# branching now, action is: 2 8 10 14
# q values are: [ 7.9165406 11.119771  13.982781  36.50673    5.0407057 46.604443 ]
# branching now, action is: 5 37 39 45
# q values are: [25.289566  8.660767 18.8595   23.689472 14.514139 24.636112]
# branching now, action is: 0 6 7 12
# q values are: [21.396152 15.618285 25.251163 10.86969  19.94588  22.838753]
# branching now, action is: 2 12 13 14
# q values are: [18.942337 14.910642 22.374573 10.763004 18.1695   20.071156]
# branching now, action is: 2 37 39 58
# q values are: [16.653038 14.290871 19.883677 12.881914 16.63635  20.1153  ]
# branching now, action is: 5 13 15 21
# q values are: [17.803558 14.492219 20.059246 10.965584 17.295923 17.952085]
# branching now, action is: 2 14 15 16
# q values are: [-28.452438  21.843964 -36.3669   181.90771  -58.425774  68.456024]
# branching now, action is: 3 5 6 7
# q values are: [18.1414   14.78015  20.949554 10.948553 17.430086 18.978695]
# branching now, action is: 2 8 9 10
# q values are: [18.436974 14.687686 20.975517 10.944998 17.592033 18.890053]
# branching now, action is: 2 27 28 29
# q values are: [19.434244 14.528921 21.67286  12.081483 17.983065 21.635246]
# branching now, action is: 2 33 34 29
# q values are: [21.56955   15.5321865 26.440075  10.106193  20.484417  23.026608 ]
# branching now, action is: 2 18 19 24
# q values are: [-255.8265     -9.398953 -358.23123   750.8909   -264.0644     55.946156]
# branching now, action is: 3 18 19 20
# q values are: [23.78651  10.89694  19.708149 20.928204 16.278952 24.369173]
# branching now, action is: 5 28 18 22
# q values are: [21.04127  15.088518 23.294388 12.325511 19.343834 23.212555]
# branching now, action is: 2 23 24 25
# q values are: [17.977015 14.691398 20.584148 11.111451 17.377506 18.674992]
# branching now, action is: 2 39 40 37
# tour is complete!
# objective_val 10758.0
# iteration: 100
# running for tsp: 792 start time: 2020-06-19 20:52:33.077587
# q values are: [17.13723  14.373833 19.383795 11.285633 16.576408 17.799282]
# branching now, action is: 2 18 20 22
# q values are: [17.247442 14.478622 19.500816 11.264536 16.651014 17.996574]
# branching now, action is: 2 22 23 17
# q values are: [20.541372 15.60628  23.14075  11.399184 18.708189 22.094398]
# branching now, action is: 2 8 10 14
# q values are: [17.705679 14.52119  20.373194 11.177005 16.93571  18.49073 ]
# branching now, action is: 2 10 11 13
# q values are: [17.175777 14.350757 18.981968 11.232998 16.615551 17.478456]
# branching now, action is: 2 13 2 8
# q values are: [25.74173  16.699795 32.31163   9.272034 23.625227 27.595978]
# branching now, action is: 2 77 84 72
# q values are: [24.386574 16.067183 30.000523  9.713732 22.283358 25.996101]
# branching now, action is: 2 13 14 2
# q values are: [18.639034 14.685004 20.990246 11.459994 17.73806  19.563545]
# branching now, action is: 2 11 12 13
# q values are: [23.477345 16.083138 28.910084  9.787018 21.82579  24.909645]
# branching now, action is: 2 56 58 59
# q values are: [19.642097 15.015559 23.238419 10.737904 18.721432 20.658768]
# branching now, action is: 2 73 77 81
# q values are: [19.57312   15.0048485 23.10352   10.829823  18.628044  20.642359 ]
# branching now, action is: 2 73 77 85
# q values are: [28.428577 17.784643 37.416027  8.452544 26.415155 30.61705 ]
# branching now, action is: 2 10 11 14
# q values are: [-157.36087    13.460017 -904.98785  1670.9916   -472.813    -102.851204]
# branching now, action is: 3 12 13 14
# q values are: [18.35792  17.302408 21.973627 20.872686 17.56822  36.85307 ]
# branching now, action is: 5 86 73 75
# q values are: [18.02507  14.76779  20.581226 10.969963 17.266354 18.848854]
# branching now, action is: 2 73 77 86
# tour is complete!
# objective_val 12251.0
# iteration: 101
# running for tsp: 336 start time: 2020-06-19 20:57:56.771716
# q values are: [23.031048 16.063356 28.679718  9.680961 21.763153 24.456371]
# branching now, action is: 2 18 36 55
# q values are: [22.993984 16.048346 28.210125  9.734369 21.587305 24.13659 ]
# branching now, action is: 2 18 35 36
# q values are: [ -597.2855   -186.64076 -1138.2595   1521.257    -967.3002   -197.42763]
# branching now, action is: 3 20 34 56
# tour is complete!
# objective_val 8957.0
# iteration: 102
# running for tsp: 634 start time: 2020-06-19 20:59:17.890630
# q values are: [24.745216 16.699322 30.821968  9.629041 22.74329  26.51218 ]
# branching now, action is: 2 4 5 27
# q values are: [20.24821  15.458791 24.42321  10.479953 19.144619 21.921982]
# branching now, action is: 2 14 33 34
# q values are: [18.436264 14.697865 20.975716 10.730041 17.839727 18.61783 ]
# branching now, action is: 2 39 40 17
# q values are: [21.223782 15.505337 26.877102  9.811928 20.767925 22.907776]
# branching now, action is: 2 7 8 27
# q values are: [16.332521 12.668647 17.98987  23.680365 14.204349 28.114784]
# branching now, action is: 5 132 133 109
# q values are: [17.184639 14.472999 19.451334 11.218702 16.535488 17.904724]
# branching now, action is: 2 0 3 4
# q values are: [17.825943 14.489225 20.11639  10.99106  17.30427  18.026102]
# branching now, action is: 2 6 9 27
# q values are: [19.358116 15.069753 23.046764 10.660753 18.54912  20.541443]
# branching now, action is: 2 4 5 6
# q values are: [21.63071  15.56867  26.358555 10.546421 20.21761  23.300068]
# branching now, action is: 2 134 137 113
# q values are: [17.349556 14.59691  19.852818 11.197123 16.617456 18.466152]
# branching now, action is: 2 6 8 9
# q values are: [20.58912   15.7076235 25.17199   10.454478  19.323528  22.777283 ]
# branching now, action is: 2 36 37 13
# q values are: [22.511414 15.736274 27.20429  10.732938 20.58488  24.075214]
# branching now, action is: 2 11 30 31
# q values are: [18.974052 14.73137  22.415909 10.994444 18.18563  20.144167]
# branching now, action is: 2 0 2 3
# q values are: [20.71868  15.292381 23.62733  11.41254  19.353512 22.149055]
# branching now, action is: 2 2 21 22
# q values are: [17.87526  14.434492 20.302032 11.437528 17.170431 18.768175]
# branching now, action is: 2 0 21 22
# q values are: [17.9778   14.7491   20.74768  11.024921 17.265766 18.870493]
# branching now, action is: 2 1 2 3
# q values are: [21.409298 15.683173 25.509949 10.458869 19.961195 22.523384]
# branching now, action is: 2 5 24 25
# q values are: [ 84.66332   16.24057  -54.70706  242.80875  -18.956657 109.35844 ]
# branching now, action is: 3 0 2 21
# q values are: [22.903635 15.980496 28.079742  9.843518 21.453403 24.188068]
# branching now, action is: 2 14 33 36
# q values are: [17.742687 14.776955 20.676674 11.169981 16.924599 19.122555]
# branching now, action is: 2 5 6 3
# q values are: [18.931269 14.920576 22.469385 10.884569 18.119827 20.161835]
# branching now, action is: 2 2 3 21
# q values are: [19.53189  15.296215 23.415363 10.646171 18.51955  21.180145]
# branching now, action is: 2 25 26 45
# q values are: [19.036242 15.054422 22.31739  10.764642 18.266909 20.002285]
# branching now, action is: 2 2 23 25
# q values are: [17.08745  14.357297 19.120491 11.197031 16.540058 17.591267]
# branching now, action is: 2 80 83 99
# tour is NOT complete, branching needed!
# iteration: 103
# running for tsp: 684 start time: 2020-06-19 21:22:14.058933
# q values are: [-7.378953 15.133642  8.412701 26.628424 14.076714  7.548997]
# branching now, action is: 3 19 20 23
# q values are: [16.023722 13.467701 20.09816  12.898614 15.53113  21.332659]
# branching now, action is: 5 20 21 24
# q values are: [24.744877 16.224007 31.443764  9.682909 23.135674 27.24405 ]
# branching now, action is: 2 0 1 3
# q values are: [24.74488  16.224007 31.443764  9.682908 23.135674 27.24405 ]
# branching now, action is: 2 0 1 2
# q values are: [28.376507 17.77985  37.356136  8.404557 26.419563 30.545387]
# branching now, action is: 2 1 2 3
# q values are: [14.790407   8.578394  12.867562  39.61596    4.5323544 32.0235   ]
# branching now, action is: 3 20 21 22
# tour is complete!
# objective_val 7582.0
# iteration: 104
# running for tsp: 494 start time: 2020-06-19 21:22:30.413725
# q values are: [34.190018  -6.6786585 29.779095  34.78131    8.424093  70.84447  ]
# branching now, action is: 3 0 8 9
# q values are: [30.039707 17.482718 40.10381   8.744856 26.769024 34.15381 ]
# branching now, action is: 2 1 8 53
# q values are: [24.841892 16.464895 31.77274   9.289676 22.987827 26.953064]
# branching now, action is: 2 1 8 52
# q values are: [32.498146  18.967825  44.487198   7.7063417 29.74403   35.85748  ]
# branching now, action is: 2 1 8 9
# q values are: [17.96714  14.517693 20.245335 10.998835 17.373991 18.257639]
# branching now, action is: 2 14 43 48
# q values are: [25.411457  16.400236  32.25542    9.6156025 23.109955  27.775188 ]
# branching now, action is: 2 4 29 50
# q values are: [25.02428  17.024368 31.568958  9.315498 23.281727 27.189266]
# branching now, action is: 2 3 28 29
# q values are: [26.742104 16.697899 34.37181   9.362751 24.144127 29.561203]
# branching now, action is: 2 4 29 51
# q values are: [26.418499 17.289848 33.814865  8.913591 24.62228  28.575237]
# branching now, action is: 2 4 29 47
# q values are: [  51.898445   21.188179 -135.12756   353.40573   -86.49887    85.76096 ]
# branching now, action is: 3 4 28 29
# q values are: [26.742104 16.697899 34.37181   9.362751 24.144127 29.561203]
# branching now, action is: 2 5 47 51
# q values are: [18.855341 14.801397 22.977913 11.175385 18.142023 20.830477]
# branching now, action is: 2 50 5 13
# q values are: [23.537539 14.609294 25.096016 12.458464 19.665714 25.703217]
# branching now, action is: 5 17 44 46
# q values are: [18.559956 14.921534 21.636688 10.837942 17.825586 19.480164]
# branching now, action is: 2 47 5 16
# q values are: [23.793713 16.189459 29.996147  9.49395  22.237797 25.545012]
# branching now, action is: 2 5 47 50
# q values are: [18.647873 14.79114  21.282913 10.747712 17.907417 18.848263]
# branching now, action is: 2 12 50 52
# q values are: [20.332422 15.644079 24.13703  10.816407 19.123707 22.034145]
# branching now, action is: 2 12 26 50
# q values are: [17.889683 14.409835 20.696854 11.135068 16.917194 18.600487]
# branching now, action is: 2 16 44 46
# q values are: [19.253422 15.020128 22.716381 10.606593 18.469473 20.219269]
# branching now, action is: 2 45 6 7
# q values are: [  56.628723   29.636284 -177.67938   435.2535   -109.82074    91.25056 ]
# branching now, action is: 3 8 9 20
# q values are: [18.424728 14.571226 20.747162 11.525162 17.528055 19.413448]
# branching now, action is: 2 5 16 28
# q values are: [28.707317 18.008104 37.496185  8.182793 26.505882 30.668827]
# branching now, action is: 2 1 8 21
# q values are: [17.190933 14.409841 19.666656 11.256972 16.659182 17.980747]
# branching now, action is: 2 17 40 46
# q values are: [19.404943 14.912628 22.881485 10.954451 18.497572 20.53832 ]
# branching now, action is: 2 50 2 16
# q values are: [22.785004 12.803287 24.4472   11.631222 17.785069 24.691643]
# branching now, action is: 5 45 6 16
# q values are: [28.314186 17.76542  37.20245   8.439174 26.341389 30.44989 ]
# branching now, action is: 2 1 8 20
# q values are: [21.947731  15.9321375 27.4087    12.56987   20.5855    25.063747 ]
# branching now, action is: 2 1 8 49
# q values are: [18.497353 14.854765 21.456078 10.810256 17.7685   19.283033]
# branching now, action is: 2 28 29 50
# q values are: [15.947368  9.999008 20.922474 13.462744 13.329836 18.659117]
# branching now, action is: 2 9 20 21
# q values are: [25.0237   16.719296 32.16964   9.268055 23.012388 27.402924]
# branching now, action is: 2 2 28 32
# q values are: [23.257996 16.283478 29.586128 10.077576 21.47715  25.86752 ]
# branching now, action is: 2 2 28 33
# q values are: [22.45869  16.217564 28.219227 10.656068 20.71366  25.093132]
# branching now, action is: 2 3 28 32
# q values are: [23.748909 16.183424 29.838196  9.335891 22.22818  25.177433]
# branching now, action is: 2 1 8 12
# q values are: [22.932022 15.838692 28.501656  9.720974 21.470303 24.458439]
# branching now, action is: 2 1 8 13
# q values are: [23.081528 12.524145 25.032394 11.595813 17.689278 25.403828]
# branching now, action is: 5 7 16 17
# q values are: [19.894047 15.033366 23.782372 10.349587 19.034534 20.728397]
# branching now, action is: 2 1 8 35
# q values are: [19.894047 15.033366 23.782372 10.349588 19.034534 20.728397]
# branching now, action is: 2 1 8 34
# q values are: [22.434025  14.111382  23.952896  12.2571335 18.892666  24.400177 ]
# branching now, action is: 5 7 17 40
# q values are: [23.422558 16.29729  28.800533 10.008083 21.638767 25.017609]
# branching now, action is: 2 50 2 7
# tour is complete!
# objective_val 10558.0
# iteration: 105
# running for tsp: 396 start time: 2020-06-19 21:27:25.031523
# q values are: [25.619955 16.330261 33.06234   9.870172 24.0937   28.7331  ]
# branching now, action is: 2 1 25 26
# branching now, action is: 2 4 6 9
# q values are: [-16.655434    8.306023   12.625387   36.90081    -2.3567762  22.035435 ]
# branching now, action is: 3 39 30 33
# q values are: [19.13917  14.99432  23.009762 10.767162 18.376314 20.542694]
# branching now, action is: 2 12 14 17
# q values are: [19.768486 15.301559 23.591549 10.512086 18.794243 21.083664]
# branching now, action is: 2 99 90 94
# q values are: [  13.640904   31.1264   -493.98343  1022.4224   -254.72154    31.303608]
# branching now, action is: 3 34 35 37
# q values are: [18.161327 14.936289 20.981838 11.205086 17.309143 19.509338]
# branching now, action is: 2 50 53 58
# tour is NOT complete, branching needed!
# iteration: 107
# running for tsp: 693 start time: 2020-06-19 21:43:06.476465
# q values are: [17.02347  14.574572 19.938576 11.973582 17.19932  18.850843]
# branching now, action is: 2 45 46 48
# q values are: [14.942275 11.488873 20.460615 10.762406 17.99283  19.209795]
# branching now, action is: 2 43 45 48
# q values are: [20.262037 15.145919 24.395924 12.924607 18.494303 24.817297]
# branching now, action is: 5 8 9 10
# q values are: [18.565062 14.971442 21.549484 11.042609 17.835014 19.594807]
# branching now, action is: 2 21 22 15
# q values are: [ 5.769056  20.346054   5.996682  60.619503   7.7997174 54.418095 ]
# branching now, action is: 3 62 63 64
# q values are: [19.434315 14.972515 22.894712 10.567779 18.67913  20.147041]
# branching now, action is: 2 8 9 12
# q values are: [-198.7554    -20.249832  -71.540535  234.16324    14.063267  -53.30164 ]
# branching now, action is: 3 8 9 10
# q values are: [17.879921  14.6309595 20.294075  11.016972  17.24421   18.408802 ]
# branching now, action is: 2 46 50 52
# q values are: [15.219963 11.652202 19.051657 12.576197 14.518173 17.189001]
# branching now, action is: 2 49 50 51
# q values are: [15.688305 13.770232 17.146263 11.651978 15.450679 15.938669]
# branching now, action is: 2 57 58 59
# q values are: [17.015028 14.097319 19.351892 11.486551 16.430986 17.58535 ]
# branching now, action is: 2 59 60 61
# q values are: [19.253422 15.020128 22.716381 10.606594 18.469473 20.219269]
# branching now, action is: 2 17 18 19
# q values are: [25.035282  7.605822 21.536669 19.243816 15.560086 25.869331]
# branching now, action is: 5 61 63 65
# q values are: [18.45338  14.863293 21.393738 10.846836 17.725763 19.295557]
# branching now, action is: 2 7 8 12
# q values are: [16.842422 14.445835 18.540756 11.427991 16.208126 17.532257]
# branching now, action is: 2 20 21 22
# q values are: [18.060783 14.597456 20.55385  10.925741 17.545973 18.319637]
# branching now, action is: 2 61 62 63
# q values are: [24.745216 16.699322 30.821968  9.629041 22.74329  26.51218 ]
# branching now, action is: 2 13 15 19
# q values are: [18.106775  14.595165  20.474098  10.8504925 17.51104   18.260061 ]
# branching now, action is: 2 33 34 27
# q values are: [18.292671 14.632212 21.223694 10.901948 17.694754 18.95372 ]
# branching now, action is: 2 29 30 23
# q values are: [18.76862  14.757262 21.837658 11.027256 17.951366 19.678352]
# branching now, action is: 2 29 30 25
# q values are: [19.707579  14.9819355 21.933659  11.572165  18.532818  20.720993 ]
# branching now, action is: 2 18 19 20
# q values are: [ -56.70425   23.96437 -157.1412   359.3563  -129.80122   71.73767]
# branching now, action is: 3 57 58 51
# q values are: [ 34.87853   16.438484 -16.809357 145.70416  -25.808292 124.03033 ]
# branching now, action is: 3 49 50 53
# q values are: [32.977215  -1.9127455 30.52665   31.671661   9.644777  69.48987  ]
# branching now, action is: 0 34 36 38
# q values are: [23.447195 15.809974 29.338196 10.228876 21.3578   25.580605]
# branching now, action is: 2 32 33 36
# q values are: [17.327297 14.511467 19.521065 11.150165 16.704788 17.963089]
# branching now, action is: 2 33 34 30
# q values are: [22.143417 15.755294 25.355392 11.537033 20.505135 23.880535]
# branching now, action is: 2 35 37 39
# q values are: [23.66489   9.912589 22.691498 15.991543 16.507029 25.359285]
# branching now, action is: 5 43 45 37
# tour is NOT complete, branching needed!
# iteration: 108
# running for tsp: 395 start time: 2020-06-19 21:48:37.092244
# q values are: [15.395491  5.277275 21.203    16.499271 10.865967 19.771042]
# branching now, action is: 2 102 103 50
# q values are: [-453.78665 -301.71573 -249.78491  475.48315 -234.13097 -121.62844]
# branching now, action is: 3 3 4 54
# q values are: [20.9533   12.332997 22.240448 11.972921 16.773561 22.885536]
# branching now, action is: 5 50 51 101
# q values are: [24.274784 15.596464 29.52042  10.529474 21.856276 26.754564]
# branching now, action is: 2 3 4 55
# q values are: [18.029331 14.585339 20.525055 10.935717 17.523785 18.299015]
# branching now, action is: 2 4 5 56
# q values are: [18.24293  14.811406 20.964506 10.928411 17.507032 19.116688]
# branching now, action is: 2 4 5 55
# q values are: [18.306335 14.676187 21.057432 10.865734 17.729435 18.744652]
# branching now, action is: 2 5 6 56
# q values are: [18.037766 14.586977 20.54509  10.935114 17.530005 18.314457]
# branching now, action is: 2 5 6 57
# q values are: [18.505209 14.677039 21.966679 11.088419 17.791943 19.879772]
# branching now, action is: 2 5 6 55
# q values are: [16.809517 14.106591 19.103344 11.542099 16.385008 17.468082]
# branching now, action is: 2 49 50 101
# q values are: [21.271366 15.522186 26.953472  9.797091 20.809101 22.963139]
# branching now, action is: 2 10 59 61
# q values are: [23.5825   14.07279  25.35254  12.06256  19.344294 25.699526]
# branching now, action is: 5 59 60 8
# q values are: [24.27346  15.593366 29.512981 10.533921 21.854431 26.756723]
# branching now, action is: 2 6 7 58
# q values are: [36.707474 19.74373  50.338318  6.829726 32.684357 41.225903]
# branching now, action is: 2 10 11 62
# q values are: [26.508352 16.835667 34.398235  8.903481 24.39031  29.139359]
# branching now, action is: 2 9 10 60
# q values are: [29.202484 17.772797 38.304142  7.784558 26.712358 31.583515]
# branching now, action is: 2 6 7 57
# q values are: [16.29897  14.196976 17.542171 11.513525 15.784664 16.662798]
# branching now, action is: 2 59 6 7
# q values are: [33.26206  19.325148 44.466362  7.232103 30.296955 36.375435]
# branching now, action is: 2 7 8 60
# q values are: [25.215794  9.38986  20.367905 21.339455 15.580699 25.186365]
# branching now, action is: 0 12 13 63
# q values are: [ 159.32303    27.83612  -117.20566   394.40475   -40.932682  123.7486  ]
# branching now, action is: 3 9 10 59
# branching now, action is: 2 24 25 26
# q values are: [22.71085  16.099096 27.830574  9.684196 21.55952  23.695808]
# branching now, action is: 2 0 9 11
# q values are: [16.96484  14.396011 18.971424 11.260499 16.398218 17.537731]
# branching now, action is: 2 4 9 0
# q values are: [24.744877 16.224007 31.443764  9.682909 23.135674 27.24405 ]
# branching now, action is: 2 1 2 4
# q values are: [28.33464  17.88754  36.915195  8.263617 26.233017 30.238476]
# branching now, action is: 2 5 8 10
# q values are: [28.33464   17.88754   36.915195   8.2636175 26.233017  30.238472 ]
# branching now, action is: 2 1 2 8
# q values are: [17.046661 13.429743 20.21077  11.931418 15.985183 18.575283]
# branching now, action is: 2 24 25 27
# q values are: [118.80289   23.299267 -76.29379  299.72012  -23.983635 105.6446  ]
# branching now, action is: 3 24 25 29
# q values are: [17.065863 14.060141 19.335106 11.718113 16.356462 18.414597]
# branching now, action is: 2 18 19 23
# q values are: [ -59.41261  -29.51307 -320.37732  537.2758  -262.72467   58.22095]
# branching now, action is: 3 19 24 25
# q values are: [ 6.65588   8.205715 20.801796 12.317134 18.979374 14.46154 ]
# branching now, action is: 2 26 28 20
# q values are: [16.783253 14.15156  18.378708 11.253136 16.427471 16.744595]
# branching now, action is: 2 26 27 22
# q values are: [24.74488  16.224007 31.443764  9.682908 23.135674 27.24405 ]
# branching now, action is: 2 1 2 3
# q values are: [18.374712 14.849962 21.700985 10.985504 17.67634  19.703835]
# branching now, action is: 2 21 22 23
# q values are: [18.878819 14.994889 21.975334 10.762676 18.069729 19.87614 ]
# branching now, action is: 2 9 11 0
# q values are: [17.108747 14.459894 19.484596 11.248966 16.382025 18.023502]
# branching now, action is: 2 4 9 11
# q values are: [22.795208 15.508107 25.056927 12.583667 20.635853 25.4977  ]
# branching now, action is: 5 7 8 9
# q values are: [20.050451 15.171899 23.570934 10.759464 18.849606 21.042648]
# branching now, action is: 2 21 22 27
# q values are: [ 7.563553   7.859249   7.1618166 49.61944    2.897089  41.29711  ]
# branching now, action is: 3 27 28 19
# q values are: [19.741917 15.020238 23.251827 10.690971 18.730425 20.469727]
# branching now, action is: 2 0 3 5
# q values are: [27.579582 17.637922 35.620888  8.25968  25.536983 29.330482]
# branching now, action is: 2 0 3 6
# q values are: [21.223785 15.505338 26.877102  9.811928 20.767925 22.907776]
# branching now, action is: 2 5 6 8
# q values are: [26.63908  17.207048 34.64834   8.531554 24.769321 28.739803]
# branching now, action is: 2 0 3 8
# q values are: [24.923824 16.55519  31.684143  9.301527 23.254305 26.813679]
# branching now, action is: 2 0 1 3
# q values are: [30.594616 17.911217 40.5277    8.260181 27.503166 33.768578]
# branching now, action is: 2 0 1 12
# q values are: [-402.5457  -131.26332 -866.8071  1228.8121  -687.98486 -104.69475]
# branching now, action is: 3 4 5 6
# q values are: [19.78917   13.872786  21.9306    12.4428215 17.872055  22.70191  ]
# branching now, action is: 5 7 9 10
# q values are: [36.55452   20.951267  52.357903   7.5320716 31.055702  43.265533 ]
# branching now, action is: 2 0 1 10
# q values are: [24.744879 16.224007 31.443764  9.682909 23.135674 27.244047]
# branching now, action is: 2 7 8 10
# q values are: [29.261055 19.388727 38.047672 12.628372 24.745216 34.498497]
# branching now, action is: 2 1 2 5
# q values are: [21.973022 15.786157 28.036     9.626986 21.36317  23.744133]
# branching now, action is: 2 1 6 10
# q values are: [21.295563 15.530464 26.99263   9.789797 20.829906 22.991783]
# branching now, action is: 2 2 3 5
# q values are: [33.50243  19.159227 45.84687   7.295426 30.310913 36.85291 ]
# branching now, action is: 2 1 6 7
# q values are: [28.857204 18.084438 37.413513  8.01021  26.50753  30.691242]
# branching now, action is: 2 1 6 11
# q values are: [16.339647 14.150308 18.116608 11.402705 15.852062 16.887173]
# branching now, action is: 2 2 3 8
# q values are: [18.033875 14.541839 20.452675 10.868292 17.513199 18.28393 ]
# branching now, action is: 2 3 4 7
# q values are: [21.317825 15.538914 27.028164  9.782583 20.84942  23.017246]
# branching now, action is: 2 1 6 12
# q values are: [17.285175 14.525738 19.870365 11.257984 16.592472 18.346895]
# branching now, action is: 2 2 3 10
# q values are: [19.019543 14.453213 22.30726  12.254822 17.703491 22.331562]
# branching now, action is: 5 2 3 7
# q values are: [15.520674  8.058928 20.721321 14.691705 12.145662 18.85168 ]
# branching now, action is: 2 8 4 6
# q values are: [-6.0699383e+01  2.8099644e+01 -3.2964600e+01  1.1565944e+02
#   8.3323479e-02  1.2899306e+01]
# branching now, action is: 3 5 6 7
# q values are: [22.05619    5.5764914  1.360959  63.760693   1.321929  35.51314  ]
# branching now, action is: 3 2 3 4
# q values are: [18.017254 12.086341 14.988006 17.376638 14.596722 17.102814]
# branching now, action is: 0 5 6 11
# q values are: [14.152936  15.5568695 13.837972  14.95171   14.853159  13.130974 ]
# branching now, action is: 1 10 11 12
# q values are: [29.021584   2.9601746 16.41655   31.933802  13.054725  26.142735 ]
# branching now, action is: 3 12 13 14
# q values are: [30.878635  17.995853  41.863293   7.9270425 27.842644  34.897694 ]
# branching now, action is: 2 3 8 11
# q values are: [39.95968  19.71466  54.199566  6.24133  34.360916 44.94184 ]
# branching now, action is: 2 13 14 15
# q values are: [-63.382427  24.135483 -45.773815 171.1481   -24.236618  68.88452 ]
# branching now, action is: 3 21 22 26
# q values are: [21.508411 14.350127 23.067543 12.319758 18.799187 23.448315]
# branching now, action is: 5 23 26 27
# tour is complete!
# objective_val 8522.0
# iteration: 161
# running for tsp: 590 start time: 2020-06-20 04:14:46.624517
# q values are: [19.617796 14.99325  22.382977 11.385578 18.477497 20.823261]
# branching now, action is: 2 3 12 15
# q values are: [16.742786  14.3037615 18.742022  11.322819  16.25427   17.42809  ]
# branching now, action is: 2 4 6 7
# q values are: [-105.52863    20.42094  -713.0979   1462.0516   -341.06464   -54.152004]
# branching now, action is: 3 4 6 11
# q values are: [21.054949 15.51224  25.974026 10.29122  20.071175 22.632988]
# branching now, action is: 2 12 13 15
# q values are: [19.998062 15.636856 24.526497 10.711484 18.770102 22.472712]
# branching now, action is: 2 7 17 19
# branching now, action is: 2 24 3 17
# q values are: [24.045261 16.524403 30.204094  9.349254 22.824423 25.340687]
# branching now, action is: 2 0 1 11
# q values are: [25.440018 17.034496 33.588448  9.985287 23.37558  28.83796 ]
# branching now, action is: 2 3 10 24
# q values are: [24.405708 16.664896 31.09021   9.05931  22.892859 26.060555]
# branching now, action is: 2 0 1 16
# q values are: [20.02755  15.084472 23.987976 10.891885 18.784998 21.647642]
# branching now, action is: 2 3 4 10
# q values are: [25.797152 16.948433 33.32669   9.363336 23.537304 28.24136 ]
# branching now, action is: 2 0 1 4
# q values are: [15.61271  14.84817  10.949698 14.787491  8.549402 15.367271]
# branching now, action is: 0 17 19 22
# q values are: [38.172276  19.47747   52.007576   6.7844467 33.497032  43.553722 ]
# branching now, action is: 2 3 4 17
# q values are: [19.127703 14.837725 22.70477  10.911202 18.275557 20.410086]
# branching now, action is: 2 17 20 22
# q values are: [34.979317 18.841358 47.44455   7.399351 30.857018 39.411316]
# branching now, action is: 2 0 1 18
# q values are: [18.792088 14.856358 22.553822 10.899118 18.089563 20.179676]
# branching now, action is: 2 0 1 3
# q values are: [27.913715 17.169415 36.12867   8.836847 25.35481  30.542927]
# branching now, action is: 2 0 1 6
# q values are: [44.868793  21.933979  62.942387   4.4691696 39.349     50.58519  ]
# branching now, action is: 2 0 1 12
# q values are: [17.763145 14.492218 20.12011  11.012451 17.156942 18.220955]
# branching now, action is: 2 6 16 22
# q values are: [20.377678 15.194262 24.495378 10.628231 19.315208 21.66547 ]
# branching now, action is: 2 6 16 17
# q values are: [22.219604 15.797478 27.189754 10.329234 20.715282 23.865417]
# branching now, action is: 2 4 6 17
# q values are: [17.094173 14.265323 20.108345 11.424473 17.042072 18.288666]
# branching now, action is: 2 6 11 14
# q values are: [18.957233 14.321382 21.98358  12.457957 17.469748 22.24146 ]
# branching now, action is: 5 12 13 21
# q values are: [18.124746 14.76948  20.576393 11.049304 17.363335 18.872458]
# branching now, action is: 2 19 20 5
# q values are: [30.552479 13.24277  35.391994 33.260628 33.662388 80.9289  ]
# branching now, action is: 5 10 17 19
# q values are: [19.44246  15.292105 23.137894 10.65667  18.414371 21.00392 ]
# branching now, action is: 2 14 17 22
# q values are: [25.619953 16.330261 33.06234   9.870171 24.093702 28.7331  ]
# branching now, action is: 2 6 11 16
# q values are: [21.271366 15.522187 26.953476  9.797089 20.809103 22.963142]
# branching now, action is: 2 0 1 22
# q values are: [27.607128 17.699455 37.362213  8.260508 25.995804 30.620213]
# branching now, action is: 2 0 1 14
# q values are: [28.355555 12.211551 33.4903   32.32347  31.945898 72.37364 ]
# branching now, action is: 5 2 18 23
# q values are: [27.183525 17.418316 35.02006   8.641415 25.368088 29.155594]
# branching now, action is: 2 2 18 23
# q values are: [24.540836 16.517752 31.109306  9.120979 22.935104 26.246796]
# branching now, action is: 2 0 1 2
# q values are: [27.445904 17.583298 35.652603  8.477238 25.649529 29.288605]
# branching now, action is: 2 2 18 20
# q values are: [30.099243  18.31043   39.923176   7.8798137 27.61911   32.85159  ]
# branching now, action is: 2 3 9 22
# q values are: [45.257977  21.812147  62.614822   4.6550837 39.228157  50.82955  ]
# branching now, action is: 2 2 10 18
# q values are: [24.74488  16.224007 31.443764  9.682909 23.135674 27.24405 ]
# branching now, action is: 2 3 4 6
# q values are: [23.219337 16.216501 30.024708  9.359833 22.338335 25.227058]
# branching now, action is: 2 2 6 10
# q values are: [22.869938 16.14855  28.159985  9.670689 21.719978 23.92213 ]
# branching now, action is: 2 5 14 17
# q values are: [23.219337 16.216503 30.024708  9.359833 22.338337 25.227058]
# branching now, action is: 2 2 6 17
# q values are: [-105.714935  -10.638505 -157.55356   320.4409   -158.24226    16.58825 ]
# branching now, action is: 3 6 11 2
# q values are: [24.812462 16.779642 32.59557   8.98391  23.621492 27.088799]
# branching now, action is: 2 3 13 23
# q values are: [20.173985 15.210947 23.646217 10.434271 19.1357   20.571144]
# branching now, action is: 2 3 4 13
# q values are: [29.669521 18.52163  39.017334 10.089268 26.129076 33.547245]
# branching now, action is: 2 3 4 9
# q values are: [18.266788 14.71107  21.623653 10.953721 17.737738 19.382772]
# branching now, action is: 2 3 4 5
# tour is NOT complete, branching needed!
# iteration: 162
# running for tsp: 243 start time: 2020-06-20 04:16:55.676485
# q values are: [24.74488  16.224007 31.443764  9.682909 23.135674 27.24405 ]
# branching now, action is: 2 0 2 3
# q values are: [24.74488  16.224009 31.443764  9.682908 23.135674 27.244047]
# branching now, action is: 2 0 1 2
# q values are: [27.640732 17.678766 35.67503   8.483424 25.564438 29.334438]
# branching now, action is: 2 0 1 5
# q values are: [28.377151 17.777803 37.36417   8.402126 26.41929  30.551971]
# branching now, action is: 2 1 2 3
# q values are: [  70.60193    32.891453 -156.47113   408.4024    -66.79329    91.24428 ]
# branching now, action is: 3 2 3 4
# q values are: [19.522932 15.259369 22.919922 10.973915 18.377184 20.775238]
# branching now, action is: 2 0 4 6
# tour is complete!
# objective_val 5159.0
# iteration: 163
# running for tsp: 783 start time: 2020-06-20 04:16:58.626183
# q values are: [25.857887 16.320337 33.560863 10.195015 24.41462  29.33561 ]
# branching now, action is: 2 4 5 6
# q values are: [22.163204 14.510167 23.859661 12.384394 19.246857 24.335388]
# branching now, action is: 5 2 8 10
# q values are: [28.718239 17.886719 38.18287   8.759777 26.720427 31.371727]
# branching now, action is: 2 1 3 6
# q values are: [28.718239 17.886719 38.18287   8.759777 26.720427 31.371727]
# branching now, action is: 2 1 3 4
# q values are: [29.007374 18.896439 39.06294  10.098382 25.752605 33.79584 ]
# branching now, action is: 2 0 3 6
# q values are: [14.949339  8.613439 21.070988 13.900531 14.745877 20.151669]
# branching now, action is: 2 3 4 6
# q values are: [14.166348   7.2237277 21.586803  14.644507  14.1128845 20.630028 ]
# branching now, action is: 2 1 3 5
# q values are: [30.395756  18.375423  41.04933    8.3550415 28.065817  33.437405 ]
# branching now, action is: 2 1 3 7
# tour is complete!
# objective_val 4587.0

# %%
# download the output
cp_qnet_test.to_csv('CPQ_test_perfo.csv')
files.download('CPQ_test_perfo.csv')
